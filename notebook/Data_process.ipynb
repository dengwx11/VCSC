# %% [markdown]
# # Preprocess the data
# This is a jupyter notebook to process the data, integerate all datas in a DataFrame.

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Load data
# * ```cell_label.txt```
# * ```data_total.txt```
# * ```data.txt```

# %%
cell_label = pd.read_table('../data/cell_label.txt')
data_all = pd.read_table('../data/data_total.txt')
data = pd.read_table('../data/data.txt')

# %% [markdown]
# ## See the data format
# There are three txt files.
# * ```cell_label.txt```
# * ```data_total.txt```
# * ```data.txt```
#
# We loaded the three files in DataFrame format

# %% [markdown]
# ### The cell type is one-hot encoding

# %%
cell_label.head(5)
# Out:
#    Granulocytes  basophils  Plasmacytoid dendritic cells  \
# 0             0          0                             0
# 1             0          0                             0
# 2             0          0                             0
# 3             0          0                             0
# 4             0          0                             0
#
#    Non-Classical Monocytes  myeloid dendritic cells  classical monocytes  \
# 0                        0                        0                    0
# 1                        0                        0                    0
# 2                        0                        0                    0
# 3                        0                        0                    0
# 4                        0                        0                    0
#
#    Natural Killer cells  Effector T killer cells  naive T killer cells  \
# 0                     0                        0                     0
# 1                     0                        0                     0
# 2                     0                        0                     0
# 3                     0                        0                     0
# 4                     0                        0                     0
#
#    Memory T killer cells  activated T killer cells  Effector T helper cells  \
# 0                      0                         0                        0
# 1                      0                         0                        0
# 2                      0                         0                        1
# 3                      0                         0                        0
# 4                      0                         0                        0
#
#    Naive T helper cells  Memory T helper cells  activated T helper cells  \
# 0                     0                      0                         0
# 1                     0                      0                         0
# 2                     0                      0                         0
# 3                     0                      0                         0
# 4                     0                      0                         0
#
#    memory B cells CD19  naive B cells CD19  plasma B cells CD19
# 0                    0                   0                    0
# 1                    0                   0                    0
# 2                    0                   0                    0
# 3                    0                   0                    0
# 4                    0                   0                    0

# %%
data_all.head(5)
# Out:
#     CD235ab    MCEMP1      ICOS      CD96       LCK     CXCR6       CD2  \
# 0  0.266458  0.843588  0.000000  0.566443  0.578018  0.426957  2.147042
# 1  0.890183  1.039873  0.977795  0.769440  0.245717  0.198752  1.953850
# 2  1.032193  1.408455  1.351160  1.229337  0.476334  0.750055  1.939668
# 3  0.722698  1.851187  0.671645  0.877242  0.000000  0.000000  0.000000
# 4  1.126662  1.804310  0.863143  0.495244  0.727941  0.000000  0.000000
#
#    HAPTOGLOBIN      FLT3     STAT4  ...     CD123     CD11c      CD14  CD16  \
# 0     0.608361  0.550156  1.029276  ...  0.000000  0.884130  0.818624   0.0
# 1     0.000000  0.000000  0.904484  ...  0.000000  0.674371  0.116559   0.0
# 2     0.662886  0.915624  1.056118  ...  0.814026  0.000000  1.245918   0.0
# 3     0.779155  0.374503  0.806161  ...  0.000000  1.621537  1.052678   0.0
# 4     0.755254  0.501104  0.756800  ...  0.000000  2.055391  1.046785   0.0
#
#        CD27    CD45RA       CD3      CD38    HLA-DR     batch
# 0  1.888936  1.527312  2.728251  0.872396  0.000000  c01_IPFH
# 1  1.547359  0.000000  2.776900  0.774546  0.000000  c01_IPFH
# 2  0.190691  1.503655  2.802467  0.000000  2.287302  c01_IPFH
# 3  0.000000  1.291378  1.121688  1.132275  1.631254  c01_IPFH
# 4  0.000000  0.000000  0.000000  0.325935  2.194841  c01_IPFH
#
# [5 rows x 31 columns]

# %%
cell_label['Unlabel cells'] = cell_label.apply(lambda x: 1 - x.sum(), axis=1)

# %%
data_all['celltype'] = cell_label.apply(lambda x: x.argmax(), axis=1)

# %%
data_all.head(5)
# Out:
#     CD235ab    MCEMP1      ICOS      CD96       LCK     CXCR6       CD2  \
# 0  0.266458  0.843588  0.000000  0.566443  0.578018  0.426957  2.147042
# 1  0.890183  1.039873  0.977795  0.769440  0.245717  0.198752  1.953850
# 2  1.032193  1.408455  1.351160  1.229337  0.476334  0.750055  1.939668
# 3  0.722698  1.851187  0.671645  0.877242  0.000000  0.000000  0.000000
# 4  1.126662  1.804310  0.863143  0.495244  0.727941  0.000000  0.000000
#
#    HAPTOGLOBIN      FLT3     STAT4  ...     CD11c      CD14  CD16      CD27  \
# 0     0.608361  0.550156  1.029276  ...  0.884130  0.818624   0.0  1.888936
# 1     0.000000  0.000000  0.904484  ...  0.674371  0.116559   0.0  1.547359
# 2     0.662886  0.915624  1.056118  ...  0.000000  1.245918   0.0  0.190691
# 3     0.779155  0.374503  0.806161  ...  1.621537  1.052678   0.0  0.000000
# 4     0.755254  0.501104  0.756800  ...  2.055391  1.046785   0.0  0.000000
#
#      CD45RA       CD3      CD38    HLA-DR     batch                 celltype
# 0  1.527312  2.728251  0.872396  0.000000  c01_IPFH            Unlabel cells
# 1  0.000000  2.776900  0.774546  0.000000  c01_IPFH            Unlabel cells
# 2  1.503655  2.802467  0.000000  2.287302  c01_IPFH  Effector T helper cells
# 3  1.291378  1.121688  1.132275  1.631254  c01_IPFH            Unlabel cells
# 4  0.000000  0.000000  0.325935  2.194841  c01_IPFH            Unlabel cells
#
# [5 rows x 32 columns]

# %%
data_all['Batch type'] = data_all[0:2].apply(lambda x: x['batch'].split('_')[-1], axis = 1)

# %%
data_all.head(2)
# Out:
#     CD235ab    MCEMP1      ICOS      CD96       LCK     CXCR6       CD2  \
# 0  0.266458  0.843588  0.000000  0.566443  0.578018  0.426957  2.147042
# 1  0.890183  1.039873  0.977795  0.769440  0.245717  0.198752  1.953850
#
#    HAPTOGLOBIN      FLT3     STAT4  ...      CD14  CD16      CD27    CD45RA  \
# 0     0.608361  0.550156  1.029276  ...  0.818624   0.0  1.888936  1.527312
# 1     0.000000  0.000000  0.904484  ...  0.116559   0.0  1.547359  0.000000
#
#         CD3      CD38  HLA-DR     batch       celltype  Batch type
# 0  2.728251  0.872396     0.0  c01_IPFH  Unlabel cells        IPFH
# 1  2.776900  0.774546     0.0  c01_IPFH  Unlabel cells        IPFH
#
# [2 rows x 33 columns]

# %%
data_all.to_csv('../processd_data.csv', index = False)
